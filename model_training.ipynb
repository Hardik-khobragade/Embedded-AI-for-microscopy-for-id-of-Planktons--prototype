# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\asus\anaconda3\lib\site-packages (8.3.199)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (2.32.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: polars in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (1.33.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\asus\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\asus\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\asus\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\asus\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\asus\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\asus\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (69.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.yaml")  # build a new model from YAML
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="file.yaml", epochs=20, imgsz=640)
# Out:
# Transferred 499/499 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.3.202 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.199  Python-3.12.3 torch-2.8.0+cpu CPU (AMD Ryzen 7 5800HS with Radeon Graphics)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=file.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=yolo11n.pt, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\ASUS\runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 1.11.1 MB/s, size: 15.9 KB)
# train: Scanning D:\SIH Prototype\datasets\labels\train.cache... 5792 images, 1913 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5792/5792 5.8Mit/s 0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 0.40.4 MB/s, size: 5.7 KB)
# val: Scanning D:\SIH Prototype\datasets\labels\val.cache... 1449 images, 447 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1449/1449 1.1Mit/s 0.0s
# Plotting labels to C:\Users\ASUS\runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\ASUS\runs\detect\train
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         0G      1.608       2.47      1.426         29        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 37:03<6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.6it/s 1:193.0sss
#                    all       1449       1003      0.811       0.46      0.596      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20         0G      1.491      1.622      1.341         27        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 32:54<5.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.8it/s 56.1s2.2ss
#                    all       1449       1003      0.431        0.6      0.508      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G      1.474      1.404      1.327         36        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 36:29<6.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.7it/s 1:092.8sss
#                    all       1449       1003      0.712       0.61      0.674      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20         0G      1.403      1.255      1.299         30        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 35:48<5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.8it/s 56.1s2.3ss
#                    all       1449       1003      0.578      0.753      0.769       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20         0G      1.368       1.15      1.274         43        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 31:34<5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.9it/s 53.4s2.2ss
#                    all       1449       1003      0.764       0.77      0.824      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20         0G      1.348        1.1      1.257         35        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 31:45<5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.8it/s 54.1s2.2ss
#                    all       1449       1003      0.793      0.722      0.808      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20         0G      1.321      1.071      1.247         32        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 35:37<6.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.7it/s 1:102.7sss
#                    all       1449       1003      0.679      0.747      0.771      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20         0G      1.296      1.007      1.227         36        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 39:13<6.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.7it/s 1:092.8sss
#                    all       1449       1003      0.745       0.87      0.871      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20         0G      1.276     0.9931      1.219         30        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 38:20<6.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.7it/s 1:072.7sss
#                    all       1449       1003      0.587      0.644      0.652      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20         0G      1.255     0.9573      1.216         35        640: 100% ━━━━━━━━━━━━ 362/362 0.0it/s 3:08:38<5.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.7it/s 1:112.6s4s
#                    all       1449       1003       0.89      0.781      0.889      0.548
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20         0G      1.226     0.8826      1.277          8        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 32:21<5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.8it/s 59.0s2.2ss
#                    all       1449       1003      0.659       0.59      0.548       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20         0G      1.199     0.8335       1.26         11        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 33:51<6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.7it/s 1:082.7sss
#                    all       1449       1003      0.791      0.869      0.873      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20         0G      1.188     0.7992       1.26         10        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 38:12<6.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.7it/s 1:082.7sss
#                    all       1449       1003      0.799      0.866      0.883       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20         0G      1.171     0.7785      1.246         11        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 31:52<5.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.8it/s 54.5s2.2ss
#                    all       1449       1003      0.809      0.834      0.889      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20         0G      1.152     0.7587      1.241         10        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 36:44<9.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.4it/s 1:604.1sss
#                    all       1449       1003      0.831      0.898      0.904      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20         0G      1.122     0.7249      1.227         10        640: 100% ━━━━━━━━━━━━ 362/362 0.1it/s 40:52<6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.7it/s 1:042.6sss
#                    all       1449       1003      0.929      0.768      0.894      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20         0G        1.1     0.6942      1.204          9        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 32:53<5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.9it/s 52.9s2.2ss
#                    all       1449       1003      0.839      0.885      0.913      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20         0G      1.087     0.6774      1.204         10        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 36:33<7.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.6it/s 1:183.0sss
#                    all       1449       1003      0.871      0.868       0.92        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20         0G      1.063     0.6506      1.192         10        640: 100% ━━━━━━━━━━━━ 362/362 0.0it/s 6:31:39<6.3s4
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.6it/s 1:113.0s0s
#                    all       1449       1003      0.879      0.881      0.925      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20         0G      1.044     0.6375      1.183         13        640: 100% ━━━━━━━━━━━━ 362/362 0.2it/s 37:52<7.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 0.7it/s 1:022.3sss
#                    all       1449       1003      0.881      0.903      0.934      0.613
#
# 20 epochs completed in 20.713 hours.
# Optimizer stripped from C:\Users\ASUS\runs\detect\train\weights\last.pt, 5.5MB
# Optimizer stripped from C:\Users\ASUS\runs\detect\train\weights\best.pt, 5.5MB
#
# Validating C:\Users\ASUS\runs\detect\train\weights\best.pt...
# Ultralytics 8.3.199  Python-3.12.3 torch-2.8.0+cpu CPU (AMD Ryzen 7 5800HS with Radeon Graphics)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 1.1it/s 43.4s1.7ss
#                    all       1449       1003      0.881      0.903      0.933      0.613
#          Cylindrotheca        195        195      0.644      0.892      0.845      0.396
#           Rhizosolenia        441        442      0.961      0.958      0.986      0.736
#            Ciliate_mix        160        160      0.993      0.994      0.989      0.772
#         Leptocylindrus        206        206      0.924      0.768      0.914      0.548
# Speed: 0.7ms preprocess, 26.5ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to C:\Users\ASUS\runs\detect\train

# %%
import cv2

# Load trained model
model = YOLO("C:/Users/ASUS/runs/detect/train/weights/best.pt")  

# Load video
cap = cv2.VideoCapture("video.mp4")  

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run detection
    results = model(frame)

    # Plot results on frame
    annotated_frame = results[0].plot()

    # Show video
    cv2.imshow("YOLOv11 Detection", annotated_frame)

    # Press q to quit
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
